# %% [markdown]
# # Plot Train Loss

# %%
import matplotlib.pyplot as plt

# Loss values for each epoch
loss_values = [
    1.0123, 1.0041, 0.9018, 0.8260, 0.7974, 0.7592, 0.7233, 0.6922, 
    0.6649, 0.6412, 0.6214, 0.6048, 0.5910, 0.5800, 0.5713, 0.5649, 
    0.5604, 0.5575, 0.5559, 0.5553
]

# Plotting the loss values
plt.figure(figsize=(10, 6))
plt.plot(range(1, 21), loss_values, marker='o', linestyle='-', label='Train Loss')
plt.title('Train Loss per Epoch', fontsize=16)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.grid(True)
plt.legend()
plt.xticks(range(1, 21))  # Show each epoch on the x-axis
plt.show()

# %% [markdown]
# # Plot Prompt Distillation Loss

# %%
import matplotlib.pyplot as plt

# Extracted loss values
loss = [1.6415, 1.5173, 1.4558, 1.3585, 1.2887, 1.2481, 1.1780, 1.1335, 1.1640, 1.0906]
dec_bce_0 = [1.5502, 1.4265, 1.2335, 1.1066, 1.2785, 1.1286, 1.1988, 1.1911, 1.1735, 1.1598]
dec_dice_0 = [1.0321, 0.9249, 0.8028, 0.7186, 0.9167, 0.7065, 0.8571, 0.8475, 0.8333, 0.8234]
dec_bce_1 = [1.5491, 1.4915, 1.4085, 1.2545, 1.2834, 1.4046, 1.2034, 1.1869, 1.1624, 1.1662]
dec_dice_1 = [1.0264, 0.9015, 0.8766, 0.7799, 0.9209, 0.8385, 0.8362, 0.8709, 0.8338, 0.8065]

# Plotting the losses in subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Losses Per Epoch', fontsize=16)

# Subplot for dec_dice_0
axs[0, 0].plot(range(1, len(dec_dice_0) + 1), dec_dice_0, marker='o', label='dec_dice_0', color='orange')
axs[0, 0].set_title('dec_dice_0')
axs[0, 0].set_xlabel('Epoch')
axs[0, 0].set_ylabel('Loss')
axs[0, 0].grid(True)

# Subplot for dec_dice_1
axs[0, 1].plot(range(1, len(dec_dice_1) + 1), dec_dice_1, marker='o', label='dec_dice_1', color='red')
axs[0, 1].set_title('dec_dice_1')
axs[0, 1].set_xlabel('Epoch')
axs[0, 1].set_ylabel('Loss')
axs[0, 1].grid(True)

# Subplot for dec_bce_0
axs[1, 0].plot(range(1, len(dec_bce_0) + 1), dec_bce_0, marker='o', label='dec_bce_0', color='green')
axs[1, 0].set_title('dec_bce_0')
axs[1, 0].set_xlabel('Epoch')
axs[1, 0].set_ylabel('Loss')
axs[1, 0].grid(True)

# Subplot for dec_bce_1
axs[1, 1].plot(range(1, len(dec_bce_1) + 1), dec_bce_1, marker='o', label='dec_bce_1', color='blue')
axs[1, 1].set_title('dec_bce_1')
axs[1, 1].set_xlabel('Epoch')
axs[1, 1].set_ylabel('Loss')
axs[1, 1].grid(True)

plt.tight_layout(rect=[0, 0, 1, 0.96])

# Plotting the total loss in a separate figure
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(loss) + 1), loss, marker='o', label='Total Loss', color='purple')
plt.title('Total Loss Per Epoch', fontsize=16)
plt.xlabel('Epoch', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.grid(True)
plt.legend()
plt.show()
