# %% [markdown]
# # Extact Prompt Encoder Weights

# %%
import torch
from pathlib import Path

# Path 
weights = Path("/home/samhq/KD/EdgeSAM/weights")
pretrained_weights_path = weights / "edge_sam_3x.pth"

# Load the pretrained weights
state_dict = torch.load(pretrained_weights_path, map_location='cpu')

# Explore keys in the state dictionary
print("Available keys in state_dict:")
for key in state_dict.keys():
   print(key)

# # Filter keys for prompt encoder and mask decoder
# prompt_encoder_weights = {k: v for k, v in state_dict.items() if "prompt_encoder" in k}
# mask_decoder_weights = {k: v for k, v in state_dict.items() if "mask_decoder" in k}

# # Save weights separately if needed
# torch.save(prompt_encoder_weights, weights / "sam_vit_h_prompt_encoder.pth")
# torch.save(mask_decoder_weights, weights / "sam_vit_h_mask_decoder.pth")

# print("Prompt encoder and mask decoder weights extracted and saved.")
# Out:
# Available keys in state_dict:
# image_encoder.features.0.0.c.weight
# image_encoder.features.0.0.bn.weight
# image_encoder.features.0.0.bn.bias
# image_encoder.features.0.0.bn.running_mean
# image_encoder.features.0.0.bn.running_var
# image_encoder.features.0.0.bn.num_batches_tracked
# image_encoder.features.0.2.c.weight
# image_encoder.features.0.2.bn.weight
# image_encoder.features.0.2.bn.bias
# image_encoder.features.0.2.bn.running_mean
# image_encoder.features.0.2.bn.running_var
# image_encoder.features.0.2.bn.num_batches_tracked
# image_encoder.features.1.token_mixer.0.conv.c.weight
# image_encoder.features.1.token_mixer.0.conv.bn.weight
# image_encoder.features.1.token_mixer.0.conv.bn.bias
# image_encoder.features.1.token_mixer.0.conv.bn.running_mean
# image_encoder.features.1.token_mixer.0.conv.bn.running_var
# image_encoder.features.1.token_mixer.0.conv.bn.num_batches_tracked
# image_encoder.features.1.token_mixer.0.conv1.c.weight
# ...
